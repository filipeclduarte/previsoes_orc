# %%
import pandas as pd

# %%
df = pd.read_excel("data/dados.xlsx")

# %%
df.head(10)
# Out:
#                           Date  Fundo Municipal de Saúde  \
# 0  2025-01-20 00:00:00.0000000              2.896785e+08
# 1  2025-01-21 00:00:00.0000000              6.088056e+07
# 2  2025-01-22 00:00:00.0000000              2.154135e+08
# 3  2025-01-23 00:00:00.0000000              1.602451e+07
# 4  2025-01-24 00:00:00.0000000              1.454993e+08
# 5  2025-01-27 00:00:00.0000000              4.140322e+05
# 6  2025-01-28 00:00:00.0000000              2.869661e+05
# 7  2025-01-29 00:00:00.0000000              7.308648e+07
# 8  2025-01-30 00:00:00.0000000              5.302478e+06
# 9  2025-01-31 00:00:00.0000000              1.977249e+07
#
#    Secretaria Municipal de Educação  Hospital do Servidor Público Municipal
# 0                      1.163883e+08                                     NaN
# 1                      7.928173e+06                                     NaN
# 2                      1.909110e+07                                     NaN
# ...

# %%
df['Data'] = pd.to_datetime(df['Date'])

# %%
df.set_index('Data')['Hospital do Servidor Público Municipal'].rolling(7).mean().plot()
# Out:
# <Axes: xlabel='Data'>

# %%
df.set_index('Data')['Secretaria Municipal de Educação'].plot()
# Out:
# <Axes: xlabel='Data'>
